# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/Users/vattikunta/Desktop/ShipSigma/Version2/Book1.csv")

# %%
df
# Out:
#     FedExInvoiceDataArchive      FedExInvoiceCanada
# 0    ,[BillToAccountNumber]  Bill-to Account Number
# 1            ,[InvoiceDate]    Child Account Number
# 2          ,[InvoiceNumber]            Invoice Date
# 3                ,[StoreID]          Invoice Number
# 4      ,[OriginalAmountDue]                Store ID
# ..                      ...                     ...
# 993                     NaN                     NaN
# 994                     NaN                     NaN
# 995                     NaN                     NaN
# 996                     NaN                     NaN
# 997                     NaN                     NaN
#
# [998 rows x 2 columns]

# %%
df = df.dropna(subset=['FedExInvoiceDataArchive'])

# %%
df
# Out:
#       FedExInvoiceDataArchive      FedExInvoiceCanada
# 0      ,[BillToAccountNumber]  Bill-to Account Number
# 1              ,[InvoiceDate]    Child Account Number
# 2            ,[InvoiceNumber]            Invoice Date
# 3                  ,[StoreID]          Invoice Number
# 4        ,[OriginalAmountDue]                Store ID
# ..                        ...                     ...
# 155        ,[PODDeliveryTime]                     NaN
# 156  ,[CustomerContractJobId]                     NaN
# 157      ,[CustomerInvoiceId]                     NaN
# 158  ,[FedExTrackProcessDate]                     NaN
# 159     ,[FedExTrackDetailId]                     NaN
#
# [160 rows x 2 columns]

# %%
def clean(strng):
    strng = strng.title()
    strng = strng.replace(" ","")
    strng = strng.replace("-","")
    return strng
    
df['FedExInvoiceCanada'] = df['FedExInvoiceCanada'].map(lambda x: clean(str(x)))

# %%
def cleaning(strng):
    strng = strng.replace(",[","")
    strng = strng.replace("]","")
    return strng
    
df['FedExInvoiceDataArchive'] = df['FedExInvoiceDataArchive'].map(lambda x: cleaning(str(x)))

# %%
#df = df.dropna(subset=['FedExInvoiceCanada'])

# %%
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',200)

# %%
df
# Out:
#                                FedExInvoiceDataArchive  \
# 0                                  BillToAccountNumber
# 1                                          InvoiceDate
# 2                                        InvoiceNumber
# 3                                              StoreID
# 4                                    OriginalAmountDue
# 5                                       CurrentBalance
# 6                                                Payor
# 7                               GroundTrackingIDPrefix
# 8                            ExpressorGroundTrackingID
# 9                           TransportationChargeAmount
# 10                                     NetChargeAmount
# 11                                         ServiceType
# 12                                       GroundService
# 13                                        ShipmentDate
# 14                                     PODDeliveryDate
# 15                                  PODServiceAreaCode
# 16                             PODSignatureDescription
# 17                                  ActualWeightAmount
# 18                                   ActualWeightUnits
# 19                                   RatedWeightAmount
# 20                                    RatedWeightUnits
# 21                                      NumberOfPieces
# 22                                        BundleNumber
# 23                                         MeterNumber
# 24                                  TDMasterTrackingID
# 25                                    ServicePackaging
# 26                                           DimLength
# 27                                            DimWidth
# 28                                           DimHeight
# 29                                          DimDivisor
# 30                                             DimUnit
# 31                                       RecipientName
# 32                                    RecipientCompany
# 33                               RecipientAddressLine1
# 34                               RecipientAddressLine2
# 35                                       RecipientCity
# 36                                      RecipientState
# 37                                    RecipientZipCode
# 38                           RecipientCountryTerritory
# 39                                      ShipperCompany
# 40                                         ShipperName
# 41                                 ShipperAddressLine1
# 42                                 ShipperAddressLine2
# 43                                         ShipperCity
# 44                                        ShipperState
# 45                                      ShipperZipCode
# 46                             ShipperCountryTerritory
# 47                           OriginalCustomerReference
# 48                                        OriginalRef2
# 49                                OriginalRef3PONumber
# 50              OriginalDepartmentReferenceDescription
# 51                            UpdatedCustomerReference
# 52                                         UpdatedRef2
# 53                                 UpdatedRef3PONumber
# 54               UpdatedDepartmentReferenceDescription
# 55                                                 RMA
# 56                       OriginalRecipientAddressLine1
# 57                       OriginalRecipientAddressLine2
# 58                               OriginalRecipientCity
# 59                              OriginalRecipientState
# 60                            OriginalRecipientZipCode
# 61                   OriginalRecipientCountryTerritory
# 62                                            ZoneCode
# 63                                      CostAllocation
# 64                               AlternateAddressLine1
# 65                               AlternateAddressLine2
# 66                                       AlternateCity
# 67                              AlternateStateProvince
# 68                                    AlternateZipCode
# 69                       AlternateCountryTerritoryCode
# 70                            CrossRefTrackingIDPrefix
# 71                                           EntryDate
# 72                                         EntryNumber
# 73                                        CustomsValue
# 74                            CustomsValueCurrencyCode
# 75                                       DeclaredValue
# 76                           DeclaredValueCurrencyCode
# 77                               CommodityDescription1
# 78                      CommodityCountryTerritoryCode1
# 79                               CommodityDescription2
# 80                      CommodityCountryTerritoryCode2
# 81                               CommodityDescription3
# 82                      CommodityCountryTerritoryCode3
# 83                               CommodityDescription4
# 84                      CommodityCountryTerritoryCode4
# 85                              CurrencyConversionDate
# 86                              CurrencyConversionRate
# 87                                   MultiweightNumber
# 88                    MultiweightTotalMultiweightUnits
# 89                MultiweightTotalShipmentChargeAmount
# 90                      MultiweightTotalShipmentWeight
# 91   GroundTrackingIDAddressCorrectionDiscountCharg...
# 92   GroundTrackingIDAddressCorrectionGrossChargeAm...
# 93                                         RatedMethod
# 94                                             SortHub
# 95                                     EstimatedWeight
# 96                                 EstimatedWeightUnit
# 97                                         PostalClass
# 98                                     ProcessCategory
# 99                                         PackageSize
# 100                               DeliveryConfirmation
# 101                                       TenderedDate
# 102                       TrackingIDChargeDescription1
# 103                            TrackingIDChargeAmount1
# 104                       TrackingIDChargeDescription2
# 105                            TrackingIDChargeAmount2
# 106                       TrackingIDChargeDescription3
# 107                            TrackingIDChargeAmount3
# 108                       TrackingIDChargeDescription4
# 109                            TrackingIDChargeAmount4
# 110                       TrackingIDChargeDescription5
# 111                            TrackingIDChargeAmount5
# 112                       TrackingIDChargeDescription6
# 113                            TrackingIDChargeAmount6
# 114                       TrackingIDChargeDescription7
# 115                            TrackingIDChargeAmount7
# 116                       TrackingIDChargeDescription8
# 117                            TrackingIDChargeAmount8
# 118                       TrackingIDChargeDescription9
# 119                            TrackingIDChargeAmount9
# 120                      TrackingIDChargeDescription10
# 121                           TrackingIDChargeAmount10
# 122                      TrackingIDChargeDescription11
# 123                           TrackingIDChargeAmount11
# 124                      TrackingIDChargeDescription12
# 125                           TrackingIDChargeAmount12
# 126                      TrackingIDChargeDescription13
# 127                           TrackingIDChargeAmount13
# 128                      TrackingIDChargeDescription14
# 129                           TrackingIDChargeAmount14
# 130                      TrackingIDChargeDescription15
# 131                           TrackingIDChargeAmount15
# 132                      TrackingIDChargeDescription16
# 133                           TrackingIDChargeAmount16
# 134                      TrackingIDChargeDescription17
# 135                           TrackingIDChargeAmount17
# 136                      TrackingIDChargeDescription18
# 137                           TrackingIDChargeAmount18
# 138                      TrackingIDChargeDescription19
# 139                           TrackingIDChargeAmount19
# 140                      TrackingIDChargeDescription20
# 141                           TrackingIDChargeAmount20
# 142                      TrackingIDChargeDescription21
# 143                           TrackingIDChargeAmount21
# 144                      TrackingIDChargeDescription22
# 145                           TrackingIDChargeAmount22
# 146                      TrackingIDChargeDescription23
# 147                           TrackingIDChargeAmount23
# 148                      TrackingIDChargeDescription24
# 149                           TrackingIDChargeAmount24
# 150                      TrackingIDChargeDescription25
# 151                           TrackingIDChargeAmount25
# 152                                      ShipmentNotes
# 153                                         CustomerId
# 154                                        ArchiveDate
# 155                                    PODDeliveryTime
# 156                              CustomerContractJobId
# 157                                  CustomerInvoiceId
# 158                              FedExTrackProcessDate
# 159                                 FedExTrackDetailId
#
#                                     FedExInvoiceCanada
# 0                                  BillToAccountNumber
# 1                                   ChildAccountNumber
# 2                                          InvoiceDate
# 3                                        InvoiceNumber
# 4                                              StoreId
# 5                                             Currency
# 6                                    OriginalAmountDue
# 7                                      TotalInvoiceDue
# 8                                               BillTo
# 9                               GroundTrackingIdPrefix
# 10                                    AirWaybillNumber
# 11                          TransportationChargeAmount
# 12                               AirWaybillTotalAmount
# 13                                         ServiceType
# 14                                       GroundService
# 15                                            ShipDate
# 16                                        TenderedDate
# 17                                             PodDate
# 18                                             PodTime
# 19                                  PodServiceAreaCode
# 20                                             PodName
# 21                                        ActualWeight
# 22                                   ActualWeightUnits
# 23                                   RatedWeightAmount
# 24                                    RatedWeightUnits
# 25                                              Pieces
# 26                                        BundleNumber
# 27                                         MeterNumber
# 28                                  Tdmastertrackingid
# 29                                         SvcpkgLabel
# 30                                           DimLength
# 31                                            DimWidth
# 32                                           DimHeight
# 33                                          DimDivisor
# 34                                             DimUnit
# 35                                RecipientContactName
# 36                                RecipientCompanyName
# 37                               RecipientAddressLine1
# 38                               RecipientAddressLine2
# 39                                RecipientAddressCity
# 40                               RecipientAddressState
# 41                              RecipientAddressPostal
# 42                   RecipientAddressCountry/Territory
# 43                                   SenderCompanyName
# 44                                   SenderContactName
# 45                                  SenderAddressLine1
# 46                                  SenderAddressLine2
# 47                                   SenderAddressCity
# 48                                  SenderAddressState
# 49                                 SenderAddressPostal
# 50                      SenderAddressCountry/Territory
# 51                                   ShipperReference1
# 52                                   ShipperReference2
# 53                                   ShipperReference3
# 54              OriginalDepartmentReferenceDescription
# 55                            UpdatedCustomerReference
# 56                                        UpdatedRef#2
# 57                               UpdatedRef#3/PoNumber
# 58               UpdatedDepartmentReferenceDescription
# 59                                                Rma#
# 60                       OriginalRecipientAddressLine1
# 61                       OriginalRecipientAddressLine2
# 62                               OriginalRecipientCity
# 63                     OriginalRecipientState/Province
# 64                     OriginalRecipientZip/PostalCode
# 65                  OriginalRecipientCountry/Territory
# 66                                            ZoneCode
# 67                                      CostAllocation
# 68                               AlternateAddressLine1
# 69                               AlternateAddressLine2
# 70                                       AlternateCity
# 71                             AlternateState/Province
# 72                             AlternateZip/PostalCode
# 73                      AlternateCountry/TerritoryCode
# 74                            CrossreftrackingidPrefix
# 75                                  Crossreftrackingid
# 76                                           EntryDate
# 77                                         EntryNumber
# 78                                        CustomsValue
# 79                            CustomsValueCurrencyCode
# 80                                       DeclaredValue
# 81                           DeclaredValueCurrencyCode
# 82                                CommodityDescription
# 83                      CommodityCountry/TerritoryCode
# 84                                CommodityDescription
# 85                      CommodityCountry/TerritoryCode
# 86                                CommodityDescription
# 87                      CommodityCountry/TerritoryCode
# 88                                CommodityDescription
# 89                      CommodityCountry/TerritoryCode
# 90                              CurrencyConversionDate
# 91                              CurrencyConversionRate
# 92                                   MultiweightNumber
# 93                    MultiweightTotalMultiweightUnits
# 94                   MultiweightTotalMultiweightWeight
# 95                MultiweightTotalShipmentChargeAmount
# 96                      MultiweightTotalShipmentWeight
# 97   GroundTrackingIdAddressCorrectionDiscountCharg...
# 98   GroundTrackingIdAddressCorrectionGrossChargeAm...
# 99                                       ShipmentNotes
# 100                              AirWaybillChargeLabel
# 101                             AirWaybillChargeAmount
# 102                              AirWaybillChargeLabel
# 103                             AirWaybillChargeAmount
# 104                              AirWaybillChargeLabel
# 105                             AirWaybillChargeAmount
# 106                              AirWaybillChargeLabel
# 107                             AirWaybillChargeAmount
# 108                              AirWaybillChargeLabel
# 109                             AirWaybillChargeAmount
# 110                              AirWaybillChargeLabel
# 111                             AirWaybillChargeAmount
# 112                              AirWaybillChargeLabel
# 113                             AirWaybillChargeAmount
# 114                              AirWaybillChargeLabel
# 115                             AirWaybillChargeAmount
# 116                              AirWaybillChargeLabel
# 117                             AirWaybillChargeAmount
# 118                              AirWaybillChargeLabel
# 119                             AirWaybillChargeAmount
# 120                              AirWaybillChargeLabel
# 121                             AirWaybillChargeAmount
# 122                              AirWaybillChargeLabel
# 123                             AirWaybillChargeAmount
# 124                              AirWaybillChargeLabel
# 125                             AirWaybillChargeAmount
# 126                              AirWaybillChargeLabel
# 127                             AirWaybillChargeAmount
# 128                              AirWaybillChargeLabel
# 129                             AirWaybillChargeAmount
# 130                              AirWaybillChargeLabel
# 131                             AirWaybillChargeAmount
# 132                              AirWaybillChargeLabel
# 133                             AirWaybillChargeAmount
# 134                              AirWaybillChargeLabel
# 135                             AirWaybillChargeAmount
# 136                              AirWaybillChargeLabel
# 137                             AirWaybillChargeAmount
# 138                              AirWaybillChargeLabel
# 139                             AirWaybillChargeAmount
# 140                              AirWaybillChargeLabel
# 141                             AirWaybillChargeAmount
# 142                              AirWaybillChargeLabel
# 143                             AirWaybillChargeAmount
# 144                              AirWaybillChargeLabel
# 145                             AirWaybillChargeAmount
# 146                              AirWaybillChargeLabel
# 147                             AirWaybillChargeAmount
# 148                              AirWaybillChargeLabel
# 149                             AirWaybillChargeAmount
# 150                                                Nan
# 151                                                Nan
# 152                                                Nan
# 153                                                Nan
# 154                                                Nan
# 155                                                Nan
# 156                                                Nan
# 157                                                Nan
# 158                                                Nan
# 159                                                Nan

# %%
mapped_data = { 
            "CurrentBalance":"TotalInvoiceDue",
            "Payor":"BillTo",
            "ExpressorGroundTrackingID":"AirWaybillNumber",
            "NetChargeAmount":"AirWaybillTotalAmount",
            "ShipmentDate":"ShipDate" ,
            "PODDeliveryDate":"PodDate",
            "PODSignatureDescription":"PodName",
            "ActualWeightAmount":"ActualWeight",
            "NumberOfPieces":"Pieces",
            "ServicePackaging":"SvcpkgLabel",
            "RecipientName":"RecipientContactName",
            "RecipientCompany":"RecipientCompanyName",
            "RecipientCity":"RecipientAddressCity",
            "RecipientState":"RecipientAddressState",
            "RecipientZipCode":"RecipientAddressPostal",
            "RecipientCountryTerritory":"RecipientAddressCountry/Territory",
            "ShipperCompany":"SenderCompanyName",
            "ShipperName":"SenderContactName",
            "ShipperAddressLine1":"SenderAddressLine1",
            "ShipperAddressLine2":"SenderAddressLine2",
            "ShipperCity":"SenderAddressCity",
            "ShipperState":"SenderAddressState",
            "ShipperZipCode":"SenderAddressPostal",
            "ShipperCountryTerritory":"SenderAddressCountry/Territory",
            "OriginalCustomerReference":"ShipperReference1",
            "OriginalRef2":"ShipperReference2",
            "OriginalRef3PONumber":"ShipperReference3",
            "UpdatedRef2":"UpdatedRef#2",
            "UpdatedRef3PONumber":"UpdatedRef#3/PoNumber",
            "RMA":"Rma#",
            "OriginalRecipientState":"OriginalRecipientState/Province",
            "OriginalRecipientZipCode":"OriginalRecipientZip/PostalCode",
            "OriginalRecipientCountryTerritory":"OriginalRecipientCountry/Territory",
            "AlternateStateProvince":"AlternateState/Province",
            "AlternateZipCode":"AlternateZip/PostalCode",
            "AlternateCountryTerritoryCode":"AlternateCountry/TerritoryCode",
            "CommodityDescription1":"CommodityDescription",
            "CommodityCountryTerritoryCode1":"CommodityCountry/TerritoryCode",
            "CommodityDescription2":"CommodityDescription",
            "CommodityCountryTerritoryCode2":"CommodityCountry/TerritoryCode",
            "CommodityDescription3":"CommodityDescription",
            "CommodityCountryTerritoryCode3":"CommodityCountry/TerritoryCode",
            "CommodityDescription4":"CommodityDescription",
            "CommodityCountryTerritoryCode4":"CommodityCountry/TerritoryCode",
            "TrackingIDChargeDescription1":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount1":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription2":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount2":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription3":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount3":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription4":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount4":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription5":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount5":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription6":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount6":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription7":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount7":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription8":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount8":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription9":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount9":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription10":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount10":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription11":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount11":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription12":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount12":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription13":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount13":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription14":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount14":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription15":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount15":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription16":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount16":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription17":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount17":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription18":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount18":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription19":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount19":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription20":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount20":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription21":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount21":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription22":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount22":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription23":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount23":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription24":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount24":"AirWaybillChargeAmount",
            "TrackingIDChargeDescription25":"AirWaybillChargeLabel",
            "TrackingIDChargeAmount25":"AirWaybillChargeAmount",
            "BillToAccountNumber":"BillToAccountNumber",
            "InvoiceDate":"InvoiceDate",
            "InvoiceNumber":"InvoiceNumber",
            "StoreID":"StoreId",
            "OriginalAmountDue":"OriginalAmountDue",
            "GroundTrackingIDPrefix":"GroundTrackingIdPrefix",
            "TransportationChargeAmount":"TransportationChargeAmount",
            "ServiceType":"ServiceType",
            "GroundService":"GroundService",
            "TenderedDate":"TenderedDate",
            "PODServiceAreaCode":"PodServiceAreaCode",
            "ActualWeightUnits":"ActualWeightUnits",
            "RatedWeightAmount":"RatedWeightAmount",
            "RatedWeightUnits":"RatedWeightUnits",
            "BundleNumber":"BundleNumber",
            "MeterNumber":"MeterNumber",
            "TDMasterTrackingID":"Tdmastertrackingid",
            "DimLength":"DimLength",
            "DimWidth":"DimWidth",
            "DimHeight":"DimHeight",
            "DimDivisor":"DimDivisor",
            "DimUnit":"DimUnit",
            "RecipientAddressLine1":"RecipientAddressLine1",
            "RecipientAddressLine2":"RecipientAddressLine2",
            "OriginalDepartmentReferenceDescription":"OriginalDepartmentReferenceDescription",
            "UpdatedCustomerReference":"UpdatedCustomerReference",
            "UpdatedDepartmentReferenceDescription":"UpdatedDepartmentReferenceDescription",
            "OriginalRecipientAddressLine1":"OriginalRecipientAddressLine1",
            "OriginalRecipientAddressLine2":"OriginalRecipientAddressLine2",
            "OriginalRecipientCity":"OriginalRecipientCity",
            "ZoneCode":"ZoneCode",
            "CostAllocation":"CostAllocation",
            "AlternateAddressLine1":"AlternateAddressLine1",
            "AlternateAddressLine2":"AlternateAddressLine2",
            "AlternateCity":"AlternateCity",
            "CrossRefTrackingIDPrefix":"CrossreftrackingidPrefix",
            "EntryDate":"EntryDate",
            "EntryNumber":"EntryNumber",
            "CustomsValue":"CustomsValue",
            "CustomsValueCurrencyCode":"CustomsValueCurrencyCode",
            "DeclaredValue":"DeclaredValue",
            "DeclaredValueCurrencyCode":"DeclaredValueCurrencyCode",
            "CurrencyConversionDate":"CurrencyConversionDate",
            "CurrencyConversionRate":"CurrencyConversionRate",
            "MultiweightNumber":"MultiweightNumber",
            "MultiweightTotalMultiweightUnits":"MultiweightTotalMultiweightUnits",
            "MultiweightTotalShipmentChargeAmount":"MultiweightTotalShipmentChargeAmount",
            "MultiweightTotalShipmentWeight":"MultiweightTotalShipmentWeight",
            "GroundTrackingIDAddressCorrectionDiscountChargeAmount":"GroundTrackingIdAddressCorrectionDiscountChargeAmount",
            "GroundTrackingIDAddressCorrectionGrossChargeAmount":"GroundTrackingIdAddressCorrectionGrossChargeAmount",
            "ShipmentNotes":"ShipmentNotes",
            "NaN":"Murali"
              }
  
# combining this new data with existing DataFrame
df["CanadaInvoice"] = df["FedExInvoiceDataArchive"].map(mapped_data)

# %%
for i in df:
    if i == 'FedExInvoiceCanada':
        df = df.drop('FedExInvoiceCanada',axis = 1)

# %%
#df

# %%
df1 = pd.DataFrame({"CanadaInvoice": ["ChildAccountNumber", "Currency", "PodTime", "Crossreftrackingid", "MultiweightTotalMultiweightWeight"]})

# %%
df = df.append(df1, ignore_index=True)

# %%
df
# Out:
#                                FedExInvoiceDataArchive  \
# 0                                  BillToAccountNumber
# 1                                          InvoiceDate
# 2                                        InvoiceNumber
# 3                                              StoreID
# 4                                    OriginalAmountDue
# 5                                       CurrentBalance
# 6                                                Payor
# 7                               GroundTrackingIDPrefix
# 8                            ExpressorGroundTrackingID
# 9                           TransportationChargeAmount
# 10                                     NetChargeAmount
# 11                                         ServiceType
# 12                                       GroundService
# 13                                        ShipmentDate
# 14                                     PODDeliveryDate
# 15                                  PODServiceAreaCode
# 16                             PODSignatureDescription
# 17                                  ActualWeightAmount
# 18                                   ActualWeightUnits
# 19                                   RatedWeightAmount
# 20                                    RatedWeightUnits
# 21                                      NumberOfPieces
# 22                                        BundleNumber
# 23                                         MeterNumber
# 24                                  TDMasterTrackingID
# 25                                    ServicePackaging
# 26                                           DimLength
# 27                                            DimWidth
# 28                                           DimHeight
# 29                                          DimDivisor
# 30                                             DimUnit
# 31                                       RecipientName
# 32                                    RecipientCompany
# 33                               RecipientAddressLine1
# 34                               RecipientAddressLine2
# 35                                       RecipientCity
# 36                                      RecipientState
# 37                                    RecipientZipCode
# 38                           RecipientCountryTerritory
# 39                                      ShipperCompany
# 40                                         ShipperName
# 41                                 ShipperAddressLine1
# 42                                 ShipperAddressLine2
# 43                                         ShipperCity
# 44                                        ShipperState
# 45                                      ShipperZipCode
# 46                             ShipperCountryTerritory
# 47                           OriginalCustomerReference
# 48                                        OriginalRef2
# 49                                OriginalRef3PONumber
# 50              OriginalDepartmentReferenceDescription
# 51                            UpdatedCustomerReference
# 52                                         UpdatedRef2
# 53                                 UpdatedRef3PONumber
# 54               UpdatedDepartmentReferenceDescription
# 55                                                 RMA
# 56                       OriginalRecipientAddressLine1
# 57                       OriginalRecipientAddressLine2
# 58                               OriginalRecipientCity
# 59                              OriginalRecipientState
# 60                            OriginalRecipientZipCode
# 61                   OriginalRecipientCountryTerritory
# 62                                            ZoneCode
# 63                                      CostAllocation
# 64                               AlternateAddressLine1
# 65                               AlternateAddressLine2
# 66                                       AlternateCity
# 67                              AlternateStateProvince
# 68                                    AlternateZipCode
# 69                       AlternateCountryTerritoryCode
# 70                            CrossRefTrackingIDPrefix
# 71                                           EntryDate
# 72                                         EntryNumber
# 73                                        CustomsValue
# 74                            CustomsValueCurrencyCode
# 75                                       DeclaredValue
# 76                           DeclaredValueCurrencyCode
# 77                               CommodityDescription1
# 78                      CommodityCountryTerritoryCode1
# 79                               CommodityDescription2
# 80                      CommodityCountryTerritoryCode2
# 81                               CommodityDescription3
# 82                      CommodityCountryTerritoryCode3
# 83                               CommodityDescription4
# 84                      CommodityCountryTerritoryCode4
# 85                              CurrencyConversionDate
# 86                              CurrencyConversionRate
# 87                                   MultiweightNumber
# 88                    MultiweightTotalMultiweightUnits
# 89                MultiweightTotalShipmentChargeAmount
# 90                      MultiweightTotalShipmentWeight
# 91   GroundTrackingIDAddressCorrectionDiscountCharg...
# 92   GroundTrackingIDAddressCorrectionGrossChargeAm...
# 93                                         RatedMethod
# 94                                             SortHub
# 95                                     EstimatedWeight
# 96                                 EstimatedWeightUnit
# 97                                         PostalClass
# 98                                     ProcessCategory
# 99                                         PackageSize
# 100                               DeliveryConfirmation
# 101                                       TenderedDate
# 102                       TrackingIDChargeDescription1
# 103                            TrackingIDChargeAmount1
# 104                       TrackingIDChargeDescription2
# 105                            TrackingIDChargeAmount2
# 106                       TrackingIDChargeDescription3
# 107                            TrackingIDChargeAmount3
# 108                       TrackingIDChargeDescription4
# 109                            TrackingIDChargeAmount4
# 110                       TrackingIDChargeDescription5
# 111                            TrackingIDChargeAmount5
# 112                       TrackingIDChargeDescription6
# 113                            TrackingIDChargeAmount6
# 114                       TrackingIDChargeDescription7
# 115                            TrackingIDChargeAmount7
# 116                       TrackingIDChargeDescription8
# 117                            TrackingIDChargeAmount8
# 118                       TrackingIDChargeDescription9
# 119                            TrackingIDChargeAmount9
# 120                      TrackingIDChargeDescription10
# 121                           TrackingIDChargeAmount10
# 122                      TrackingIDChargeDescription11
# 123                           TrackingIDChargeAmount11
# 124                      TrackingIDChargeDescription12
# 125                           TrackingIDChargeAmount12
# 126                      TrackingIDChargeDescription13
# 127                           TrackingIDChargeAmount13
# 128                      TrackingIDChargeDescription14
# 129                           TrackingIDChargeAmount14
# 130                      TrackingIDChargeDescription15
# 131                           TrackingIDChargeAmount15
# 132                      TrackingIDChargeDescription16
# 133                           TrackingIDChargeAmount16
# 134                      TrackingIDChargeDescription17
# 135                           TrackingIDChargeAmount17
# 136                      TrackingIDChargeDescription18
# 137                           TrackingIDChargeAmount18
# 138                      TrackingIDChargeDescription19
# 139                           TrackingIDChargeAmount19
# 140                      TrackingIDChargeDescription20
# 141                           TrackingIDChargeAmount20
# 142                      TrackingIDChargeDescription21
# 143                           TrackingIDChargeAmount21
# 144                      TrackingIDChargeDescription22
# 145                           TrackingIDChargeAmount22
# 146                      TrackingIDChargeDescription23
# 147                           TrackingIDChargeAmount23
# 148                      TrackingIDChargeDescription24
# 149                           TrackingIDChargeAmount24
# 150                      TrackingIDChargeDescription25
# 151                           TrackingIDChargeAmount25
# 152                                      ShipmentNotes
# 153                                         CustomerId
# 154                                        ArchiveDate
# 155                                    PODDeliveryTime
# 156                              CustomerContractJobId
# 157                                  CustomerInvoiceId
# 158                              FedExTrackProcessDate
# 159                                 FedExTrackDetailId
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
#
#                                          CanadaInvoice
# 0                                  BillToAccountNumber
# 1                                          InvoiceDate
# 2                                        InvoiceNumber
# 3                                              StoreId
# 4                                    OriginalAmountDue
# 5                                      TotalInvoiceDue
# 6                                               BillTo
# 7                               GroundTrackingIdPrefix
# 8                                     AirWaybillNumber
# 9                           TransportationChargeAmount
# 10                               AirWaybillTotalAmount
# 11                                         ServiceType
# 12                                       GroundService
# 13                                            ShipDate
# 14                                             PodDate
# 15                                  PodServiceAreaCode
# 16                                             PodName
# 17                                        ActualWeight
# 18                                   ActualWeightUnits
# 19                                   RatedWeightAmount
# 20                                    RatedWeightUnits
# 21                                              Pieces
# 22                                        BundleNumber
# 23                                         MeterNumber
# 24                                  Tdmastertrackingid
# 25                                         SvcpkgLabel
# 26                                           DimLength
# 27                                            DimWidth
# 28                                           DimHeight
# 29                                          DimDivisor
# 30                                             DimUnit
# 31                                RecipientContactName
# 32                                RecipientCompanyName
# 33                               RecipientAddressLine1
# 34                               RecipientAddressLine2
# 35                                RecipientAddressCity
# 36                               RecipientAddressState
# 37                              RecipientAddressPostal
# 38                   RecipientAddressCountry/Territory
# 39                                   SenderCompanyName
# 40                                   SenderContactName
# 41                                  SenderAddressLine1
# 42                                  SenderAddressLine2
# 43                                   SenderAddressCity
# 44                                  SenderAddressState
# 45                                 SenderAddressPostal
# 46                      SenderAddressCountry/Territory
# 47                                   ShipperReference1
# 48                                   ShipperReference2
# 49                                   ShipperReference3
# 50              OriginalDepartmentReferenceDescription
# 51                            UpdatedCustomerReference
# 52                                        UpdatedRef#2
# 53                               UpdatedRef#3/PoNumber
# 54               UpdatedDepartmentReferenceDescription
# 55                                                Rma#
# 56                       OriginalRecipientAddressLine1
# 57                       OriginalRecipientAddressLine2
# 58                               OriginalRecipientCity
# 59                     OriginalRecipientState/Province
# 60                     OriginalRecipientZip/PostalCode
# 61                  OriginalRecipientCountry/Territory
# 62                                            ZoneCode
# 63                                      CostAllocation
# 64                               AlternateAddressLine1
# 65                               AlternateAddressLine2
# 66                                       AlternateCity
# 67                             AlternateState/Province
# 68                             AlternateZip/PostalCode
# 69                      AlternateCountry/TerritoryCode
# 70                            CrossreftrackingidPrefix
# 71                                           EntryDate
# 72                                         EntryNumber
# 73                                        CustomsValue
# 74                            CustomsValueCurrencyCode
# 75                                       DeclaredValue
# 76                           DeclaredValueCurrencyCode
# 77                                CommodityDescription
# 78                      CommodityCountry/TerritoryCode
# 79                                CommodityDescription
# 80                      CommodityCountry/TerritoryCode
# 81                                CommodityDescription
# 82                      CommodityCountry/TerritoryCode
# 83                                CommodityDescription
# 84                      CommodityCountry/TerritoryCode
# 85                              CurrencyConversionDate
# 86                              CurrencyConversionRate
# 87                                   MultiweightNumber
# 88                    MultiweightTotalMultiweightUnits
# 89                MultiweightTotalShipmentChargeAmount
# 90                      MultiweightTotalShipmentWeight
# 91   GroundTrackingIdAddressCorrectionDiscountCharg...
# 92   GroundTrackingIdAddressCorrectionGrossChargeAm...
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                       TenderedDate
# 102                              AirWaybillChargeLabel
# 103                             AirWaybillChargeAmount
# 104                              AirWaybillChargeLabel
# 105                             AirWaybillChargeAmount
# 106                              AirWaybillChargeLabel
# 107                             AirWaybillChargeAmount
# 108                              AirWaybillChargeLabel
# 109                             AirWaybillChargeAmount
# 110                              AirWaybillChargeLabel
# 111                             AirWaybillChargeAmount
# 112                              AirWaybillChargeLabel
# 113                             AirWaybillChargeAmount
# 114                              AirWaybillChargeLabel
# 115                             AirWaybillChargeAmount
# 116                              AirWaybillChargeLabel
# 117                             AirWaybillChargeAmount
# 118                              AirWaybillChargeLabel
# 119                             AirWaybillChargeAmount
# 120                              AirWaybillChargeLabel
# 121                             AirWaybillChargeAmount
# 122                              AirWaybillChargeLabel
# 123                             AirWaybillChargeAmount
# 124                              AirWaybillChargeLabel
# 125                             AirWaybillChargeAmount
# 126                              AirWaybillChargeLabel
# 127                             AirWaybillChargeAmount
# 128                              AirWaybillChargeLabel
# 129                             AirWaybillChargeAmount
# 130                              AirWaybillChargeLabel
# 131                             AirWaybillChargeAmount
# 132                              AirWaybillChargeLabel
# 133                             AirWaybillChargeAmount
# 134                              AirWaybillChargeLabel
# 135                             AirWaybillChargeAmount
# 136                              AirWaybillChargeLabel
# 137                             AirWaybillChargeAmount
# 138                              AirWaybillChargeLabel
# 139                             AirWaybillChargeAmount
# 140                              AirWaybillChargeLabel
# 141                             AirWaybillChargeAmount
# 142                              AirWaybillChargeLabel
# 143                             AirWaybillChargeAmount
# 144                              AirWaybillChargeLabel
# 145                             AirWaybillChargeAmount
# 146                              AirWaybillChargeLabel
# 147                             AirWaybillChargeAmount
# 148                              AirWaybillChargeLabel
# 149                             AirWaybillChargeAmount
# 150                              AirWaybillChargeLabel
# 151                             AirWaybillChargeAmount
# 152                                      ShipmentNotes
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                 ChildAccountNumber
# 161                                           Currency
# 162                                            PodTime
# 163                                 Crossreftrackingid
# 164                  MultiweightTotalMultiweightWeight

# %%
df.to_csv("/Users/vattikunta/Desktop/ShipSigma\version_3.csv", index = False)
